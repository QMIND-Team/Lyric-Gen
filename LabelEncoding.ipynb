# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
df = pd.read_csv('/Users/james/Desktop/QU/2nd Year/QMIND/Data/Test.csv')

for row in range(df.shape[0]):
    val = ord(df['Output'][row])
    df['Output'][row] = val
    
    if val not in df:
        df[val] = 0
    
    df[val][row] = 1
del df['Output']
df
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     Seed  110  99  101  32  119  97  117  115
# 0   This is a long sente    1   0    0   0    0   0    0    0
# 1   his is a long senten    0   1    0   0    0   0    0    0
# 2   is is a long sentenc    0   0    1   0    0   0    0    0
# 3   s is a long sentence    0   0    0   1    0   0    0    0
# 4    is a long sentence     0   0    0   0    1   0    0    0
# ...
